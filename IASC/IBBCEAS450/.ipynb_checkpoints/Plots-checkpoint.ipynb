# %%
import h5py
import glob
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import CESfunctionsIASC as cf
from matplotlib.ticker import AutoMinorLocator

# %%
meas = np.loadtxt('measurements.txt')
wvs = np.loadtxt('waves.txt')
zero = np.loadtxt('zero.txt')
i0 = np.average(zero,axis=1)
sigma_ray=np.load('sigma_ray.npy')

# %%
alpha=cf.extinction_w_ray(meas[:,68], i0, .99998, 500,101335,293.15,sigma_ray)
alpha.shape
# Out:
# (1024,)

# %%
f = plt.figure(figsize=(19,14))
ax1 = f.add_subplot(111)
#cal_CEAS360=.90
#cal_CEAS450=.857
#cal_CEAS660=.857
#ax1.plot(crds405_dt,np.where(crds405_no2==0, np.nan, crds405_no2),'-k',alpha=1, label="CRDS405")
ax1.plot(wvs,i0,'-k',linewidth=3.0,alpha=1, label="I$_0$")
#ax1.plot(wvs,meas[:,68],'-r',linewidth=3.0,alpha=1, label="I$_{blank}$")
ax1.plot(wvs,meas[:,470],'-r',linewidth=3.0,alpha=1, label="I$_{sample}$")
#ax1.plot(ceas450_dt,ceas450_no2*cal_CEAS450,'-r',alpha=1, label="CEAS450")
#ax1.plot(ceas660_dt,ceas660_no2*cal_CEAS660,'-b',alpha=1, label="CEAS660")

#ax1.plot(model_time_1,model_no2_1/2.5e10,'-c',linewidth=3.0,alpha=1, label="MCMv3.3.1")
#ax1.plot(model_time_2,model_no2_2/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_3,model_no2_3/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_1,model_no2_1/2.5e10,'--g',linewidth=3.0,alpha=.6, label="MCMv3.3.1 + NO$_Y$ conversion")
#ax1.plot(model_time_2,model_no2_2a/2.5e10,'--g',linewidth=3.0,alpha=.6)
#ax1.plot(model_time_3,model_no2_3a/2.5e10,'--g',linewidth=3.0,alpha=.6)


#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


ax1.set_xlim(625,700)
#ax1.set_ylim(8,32)


#ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
#ax1.set_xlabel('time [hr:min]',size=26)
#ax1.set_ylabel('n(NO$_2$) [ppbv]',size=26)
ax1.set_xlabel('Wavelength [nm]',size=26)
ax1.set_ylabel('Intensity [counts]',size=26)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
ax1.legend(fontsize=36, loc='upper right')

ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=26,top=True, right=True)
ax1.tick_params(which='minor', length=4,top=True, right=True)
#ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
#ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,4,10,14,0),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,4,10,15,30),0,50, colors='k', linestyles= 'dashed')
ax1.yaxis.offsetText.set_fontsize(24)
ax1.ticklabel_format(axis='y', style='sci',useMathText=True)

for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(2)

#ax1.grid()
plt.savefig("no3_resonanceIs.png",bbox_inches='tight')

# %%
zero.shape
# Out:
# (1024, 10)

# %%
i0.shape
# Out:
# (1024,)

# %%
alpha=cf.extinction_w_ray(meas[:,470], i0, .99998, 500,101335,293.15,sigma_ray)
alpha.shape

f = plt.figure(figsize=(19,8))
ax1 = f.add_subplot(111)
#cal_CEAS360=.90
#cal_CEAS450=.857
#cal_CEAS660=.857
#ax1.plot(crds405_dt,np.where(crds405_no2==0, np.nan, crds405_no2),'-k',alpha=1, label="CRDS405")
ax1.plot(wvs,alpha,'-k',linewidth=3.0,alpha=1, label="I$_0$")
#ax1.plot(wvs,meas[:,470],'-r',linewidth=3.0,alpha=1, label="I$_s$")
#ax1.plot(ceas450_dt,ceas450_no2*cal_CEAS450,'-r',alpha=1, label="CEAS450")
#ax1.plot(ceas660_dt,ceas660_no2*cal_CEAS660,'-b',alpha=1, label="CEAS660")

#ax1.plot(model_time_1,model_no2_1/2.5e10,'-c',linewidth=3.0,alpha=1, label="MCMv3.3.1")
#ax1.plot(model_time_2,model_no2_2/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_3,model_no2_3/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_1,model_no2_1/2.5e10,'--g',linewidth=3.0,alpha=.6, label="MCMv3.3.1 + NO$_Y$ conversion")
#ax1.plot(model_time_2,model_no2_2a/2.5e10,'--g',linewidth=3.0,alpha=.6)
#ax1.plot(model_time_3,model_no2_3a/2.5e10,'--g',linewidth=3.0,alpha=.6)


#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


ax1.set_xlim(650,672)
ax1.set_ylim(1.5e-8,7.5e-8)


#ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
#ax1.set_xlabel('time [hr:min]',size=26)
#ax1.set_ylabel('n(NO$_2$) [ppbv]',size=26)
ax1.set_xlabel('wavelength [nm]',size=26)
ax1.set_ylabel('extinction [cm$^{-1}$]',size=26)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
#ax1.legend(fontsize=26, loc='upper right')

ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=24,top=True, right=True)
ax1.tick_params(which='minor', length=4,top=True, right=True)
#ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
#ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,4,10,14,0),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,4,10,15,30),0,50, colors='k', linestyles= 'dashed')
ax1.ticklabel_format(axis='y', style='sci',useMathText=True)
ax1.yaxis.offsetText.set_fontsize(26)
#ax1.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(2)
#ax1.grid()
plt.savefig("no3_extis.png",bbox_inches='tight')

# %%
alpha=cf.extinction_w_ray(meas[:,68], i0, .99998, 500,101335,293.15,sigma_ray)
alpha.shape

f = plt.figure(figsize=(19,8))
ax1 = f.add_subplot(111)
#cal_CEAS360=.90
#cal_CEAS450=.857
#cal_CEAS660=.857
#ax1.plot(crds405_dt,np.where(crds405_no2==0, np.nan, crds405_no2),'-k',alpha=1, label="CRDS405")
ax1.plot(wvs,alpha,'-k',linewidth=3.0,alpha=1, label="I$_0$")
#ax1.plot(wvs,meas[:,470],'-r',linewidth=3.0,alpha=1, label="I$_s$")
#ax1.plot(ceas450_dt,ceas450_no2*cal_CEAS450,'-r',alpha=1, label="CEAS450")
#ax1.plot(ceas660_dt,ceas660_no2*cal_CEAS660,'-b',alpha=1, label="CEAS660")

#ax1.plot(model_time_1,model_no2_1/2.5e10,'-c',linewidth=3.0,alpha=1, label="MCMv3.3.1")
#ax1.plot(model_time_2,model_no2_2/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_3,model_no2_3/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_1,model_no2_1/2.5e10,'--g',linewidth=3.0,alpha=.6, label="MCMv3.3.1 + NO$_Y$ conversion")
#ax1.plot(model_time_2,model_no2_2a/2.5e10,'--g',linewidth=3.0,alpha=.6)
#ax1.plot(model_time_3,model_no2_3a/2.5e10,'--g',linewidth=3.0,alpha=.6)


#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


ax1.set_xlim(650,672)
ax1.set_ylim(1.45e-9,2.35e-9)


#ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
#ax1.set_xlabel('time [hr:min]',size=26)
#ax1.set_ylabel('n(NO$_2$) [ppbv]',size=26)
ax1.set_xlabel('wavelength [nm]',size=26)
ax1.set_ylabel('extinction [cm$^{-1}$]',size=26)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
#ax1.legend(fontsize=26, loc='upper right')

ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=24,top=True, right=True)
ax1.tick_params(which='minor', length=4,top=True, right=True)
#ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
#ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,4,10,14,0),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,4,10,15,30),0,50, colors='k', linestyles= 'dashed')
ax1.ticklabel_format(axis='y', style='sci',useMathText=True)
ax1.yaxis.offsetText.set_fontsize(26)
#ax1.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(2)
#ax1.grid()
plt.savefig("no3_exti0.png",bbox_inches='tight')

# %%
alpha=cf.extinction_w_ray(meas[:,150], i0, .99998, 500,101335,293.15,sigma_ray)
alpha.shape

f = plt.figure(figsize=(19,8))
ax1 = f.add_subplot(111)
#cal_CEAS360=.90
#cal_CEAS450=.857
#cal_CEAS660=.857
#ax1.plot(crds405_dt,np.where(crds405_no2==0, np.nan, crds405_no2),'-k',alpha=1, label="CRDS405")
ax1.plot(wvs,alpha,'-k',linewidth=3.0,alpha=1, label="I$_0$")
#ax1.plot(wvs,meas[:,470],'-r',linewidth=3.0,alpha=1, label="I$_s$")
#ax1.plot(ceas450_dt,ceas450_no2*cal_CEAS450,'-r',alpha=1, label="CEAS450")
#ax1.plot(ceas660_dt,ceas660_no2*cal_CEAS660,'-b',alpha=1, label="CEAS660")

#ax1.plot(model_time_1,model_no2_1/2.5e10,'-c',linewidth=3.0,alpha=1, label="MCMv3.3.1")
#ax1.plot(model_time_2,model_no2_2/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_3,model_no2_3/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_1,model_no2_1/2.5e10,'--g',linewidth=3.0,alpha=.6, label="MCMv3.3.1 + NO$_Y$ conversion")
#ax1.plot(model_time_2,model_no2_2a/2.5e10,'--g',linewidth=3.0,alpha=.6)
#ax1.plot(model_time_3,model_no2_3a/2.5e10,'--g',linewidth=3.0,alpha=.6)


#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


ax1.set_xlim(650,672)
#ax1.set_ylim(3e-9,5e-9)


#ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
#ax1.set_xlabel('time [hr:min]',size=26)
#ax1.set_ylabel('n(NO$_2$) [ppbv]',size=26)
ax1.set_xlabel('wavelength [nm]',size=26)
ax1.set_ylabel('extinction [cm$^{-1}$]',size=26)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
#ax1.legend(fontsize=26, loc='upper right')

ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=24,top=True, right=True)
ax1.tick_params(which='minor', length=4,top=True, right=True)
#ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
#ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,4,10,14,0),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,4,10,15,30),0,50, colors='k', linestyles= 'dashed')
ax1.ticklabel_format(axis='y', style='sci',useMathText=True)
ax1.yaxis.offsetText.set_fontsize(26)
#ax1.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(2)
#ax1.grid()
plt.savefig("no3_exti0.png",bbox_inches='tight')

# %%
times = np.loadtxt('time.txt',dtype=('U', 19))
dates = [dt.datetime.strptime(i,'%Y/%m/%d-%H:%M:%S') for i in times]

# %%
no3 = np.loadtxt('no3.txt')

# %%
dates
# Out:
# [datetime.datetime(2024, 4, 10, 11, 40, 2),
#  datetime.datetime(2024, 4, 10, 11, 40, 20),
#  datetime.datetime(2024, 4, 10, 11, 40, 37),
#  datetime.datetime(2024, 4, 10, 11, 40, 55),
#  datetime.datetime(2024, 4, 10, 11, 41, 12),
#  datetime.datetime(2024, 4, 10, 11, 41, 30),
#  datetime.datetime(2024, 4, 10, 11, 41, 48),
#  datetime.datetime(2024, 4, 10, 11, 42, 5),
#  datetime.datetime(2024, 4, 10, 11, 42, 23),
#  datetime.datetime(2024, 4, 10, 11, 42, 41),
#  datetime.datetime(2024, 4, 10, 11, 42, 58),
#  datetime.datetime(2024, 4, 10, 11, 43, 16),
#  datetime.datetime(2024, 4, 10, 11, 43, 33),
#  datetime.datetime(2024, 4, 10, 11, 43, 51),
#  datetime.datetime(2024, 4, 10, 11, 44, 9),
#  datetime.datetime(2024, 4, 10, 11, 44, 26),
#  datetime.datetime(2024, 4, 10, 11, 44, 44),
#  datetime.datetime(2024, 4, 10, 11, 45, 2),
#  datetime.datetime(2024, 4, 10, 11, 45, 19),
#  datetime.datetime(2024, 4, 10, 11, 45, 37),
#  datetime.datetime(2024, 4, 10, 11, 45, 54),
# ...

# %%
f = plt.figure(figsize=(19,14))
ax1 = f.add_subplot(111)
#cal_CEAS360=.90
#cal_CEAS450=.857
#cal_CEAS660=.857
#ax1.plot(crds405_dt,np.where(crds405_no2==0, np.nan, crds405_no2),'-k',alpha=1, label="CRDS405")
ax1.plot(dates[615:732],no3[615:732],'-k',linewidth=3.0,alpha=1, label="I$_0$")
#ax1.plot(wvs,meas[:,470],'-r',linewidth=3.0,alpha=1, label="I$_s$")
#ax1.plot(ceas450_dt,ceas450_no2*cal_CEAS450,'-r',alpha=1, label="CEAS450")
#ax1.plot(ceas660_dt,ceas660_no2*cal_CEAS660,'-b',alpha=1, label="CEAS660")

#ax1.plot(model_time_1,model_no2_1/2.5e10,'-c',linewidth=3.0,alpha=1, label="MCMv3.3.1")
#ax1.plot(model_time_2,model_no2_2/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_3,model_no2_3/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_1,model_no2_1/2.5e10,'--g',linewidth=3.0,alpha=.6, label="MCMv3.3.1 + NO$_Y$ conversion")
#ax1.plot(model_time_2,model_no2_2a/2.5e10,'--g',linewidth=3.0,alpha=.6)
#ax1.plot(model_time_3,model_no2_3a/2.5e10,'--g',linewidth=3.0,alpha=.6)


#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


#ax1.set_xlim(650,672)
#ax1.set_ylim(1.5e-8,7.5e-8)


ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
#ax1.set_xlabel('time [hr:min]',size=26)
#ax1.set_ylabel('n(NO$_3$) [ppbv]',size=26)
#ax1.set_xlabel('wavelength [nm]',size=26)
#ax1.set_ylabel('extinction [cm$^{-1}$]',size=26)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
#ax1.legend(fontsize=26, loc='upper right')

ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=26,top=True, right=True)
ax1.tick_params(which='minor', length=4,top=True, right=True)
#ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
#ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,4,10,14,0),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,4,10,15,30),0,50, colors='k', linestyles= 'dashed')

for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(2)

#ax1.grid()
plt.savefig("no3_std.png",bbox_inches='tight')

# %%
np.std(no3[615:732])
# Out:
# 0.00017647946465927883

# %%
dfmbo1 = pd.read_csv('M241009.txt', sep=' ', header=None,
                 names=['time','no3','no2','h2o'],
                 index_col='time',parse_dates=['time']
                )

dfmbo2 = pd.read_csv('M241011.txt', sep=' ', header=None,
                 names=['time','no3','no2','h2o'],
                 index_col='time',parse_dates=['time']
                )

dfcat1 = pd.read_csv('M241025.txt', sep=' ', header=None,
                 names=['time','no3','no2','h2o'],
                 index_col='time',parse_dates=['time']
                )

dffar1 = pd.read_csv('M241113.txt', sep=' ', header=None,
                 names=['time','no3','no2','h2o'],
                 index_col='time',parse_dates=['time']
                )
dffar2 = pd.read_csv('M241114.txt', sep=' ', header=None,
                 names=['time','no3','no2','h2o'],
                 index_col='time',parse_dates=['time']
                )

dffar3 = pd.read_csv('M241118.txt', sep=' ', header=None,
                 names=['time','no3','no2','h2o'],
                 index_col='time',parse_dates=['time']
                )
dffar4 = pd.read_csv('M241120.txt', sep=' ', header=None,
                 names=['time','no3','no2','h2o'],
                 index_col='time',parse_dates=['time']
                )
dfska1 = pd.read_csv('M241129.txt', sep=' ', header=None,
                 names=['time','no3','no2','h2o'],
                 index_col='time',parse_dates=['time']
                )
dfska2 = pd.read_csv('M241203.txt', sep=' ', header=None,
                 names=['time','no3','no2','h2o'],
                 index_col='time',parse_dates=['time']
                )

# %%
dfcat1
# Out:
#                           no3         no2            h2o
# time
# 2024-10-25 10:57:44 -0.000029   -0.122358    2368.289288
# 2024-10-25 10:58:03 -0.000112   -0.174147   -1621.936159
# 2024-10-25 10:58:23 -0.000018   -0.154239    3994.371528
# 2024-10-25 10:58:42 -0.000070   -0.247320    8306.605650
# 2024-10-25 10:59:02 -0.000054   -0.211751    9855.820199
# ...                       ...         ...            ...
# 2024-10-25 16:55:36  0.026404  198.561426  225338.036442
# 2024-10-25 16:55:55  0.026987  197.146802  227634.874783
# 2024-10-25 16:56:15  0.027160  194.387657  214691.389984
# 2024-10-25 16:56:34  0.027688  192.819457  214523.676155
# 2024-10-25 16:56:54  0.027866  189.309366  208772.860045
#
# [1104 rows x 3 columns]

# %%
f = plt.figure(figsize=(19,14))
ax1 = f.add_subplot(111)
#cal_CEAS360=.90
#cal_CEAS450=.857
#cal_CEAS660=.857
#ax1.plot(crds405_dt,np.where(crds405_no2==0, np.nan, crds405_no2),'-k',alpha=1, label="CRDS405")
ax1.plot(dfcat1.index,dfcat1.no3,'-k',linewidth=3.0,alpha=1, label="I$_0$")
#ax1.plot(wvs,meas[:,470],'-r',linewidth=3.0,alpha=1, label="I$_s$")
#ax1.plot(ceas450_dt,ceas450_no2*cal_CEAS450,'-r',alpha=1, label="CEAS450")
#ax1.plot(ceas660_dt,ceas660_no2*cal_CEAS660,'-b',alpha=1, label="CEAS660")

#ax1.plot(model_time_1,model_no2_1/2.5e10,'-c',linewidth=3.0,alpha=1, label="MCMv3.3.1")
#ax1.plot(model_time_2,model_no2_2/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_3,model_no2_3/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_1,model_no2_1/2.5e10,'--g',linewidth=3.0,alpha=.6, label="MCMv3.3.1 + NO$_Y$ conversion")
#ax1.plot(model_time_2,model_no2_2a/2.5e10,'--g',linewidth=3.0,alpha=.6)
#ax1.plot(model_time_3,model_no2_3a/2.5e10,'--g',linewidth=3.0,alpha=.6)


#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


#ax1.set_xlim(650,672)
#ax1.set_ylim(1.5e-8,7.5e-8)


ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
#ax1.set_xlabel('time [hr:min]',size=26)
#ax1.set_ylabel('n(NO$_3$) [ppbv]',size=26)
#ax1.set_xlabel('wavelength [nm]',size=26)
#ax1.set_ylabel('extinction [cm$^{-1}$]',size=26)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
#ax1.legend(fontsize=26, loc='upper right')

ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=22,top=True, right=True)
ax1.tick_params(which='minor', length=4,top=True, right=True)
#ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
#ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,10,25,13,40),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,10,25,14,10),0,50, colors='k', linestyles= 'dashed')
ax1.set_xlim(dt.datetime(2024,10,25,13,40),dt.datetime(2024,10,25,14,10))
ax1.set_ylim(-.001,.01)
for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(2)

#ax1.grid()
plt.savefig("no3_catB.png",bbox_inches='tight')

# %%
f = plt.figure(figsize=(8,6))
ax1 = f.add_subplot(111)
#cal_CEAS360=.90
#cal_CEAS450=.857
#cal_CEAS660=.857
#ax1.plot(crds405_dt,np.where(crds405_no2==0, np.nan, crds405_no2),'-k',alpha=1, label="CRDS405")
ax1.plot(dfcat1.index,dfcat1.no3,'-k',linewidth=3.0,alpha=1, label="I$_0$")
#ax1.plot(wvs,meas[:,470],'-r',linewidth=3.0,alpha=1, label="I$_s$")
#ax1.plot(ceas450_dt,ceas450_no2*cal_CEAS450,'-r',alpha=1, label="CEAS450")
#ax1.plot(ceas660_dt,ceas660_no2*cal_CEAS660,'-b',alpha=1, label="CEAS660")

#ax1.plot(model_time_1,model_no2_1/2.5e10,'-c',linewidth=3.0,alpha=1, label="MCMv3.3.1")
#ax1.plot(model_time_2,model_no2_2/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_3,model_no2_3/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_1,model_no2_1/2.5e10,'--g',linewidth=3.0,alpha=.6, label="MCMv3.3.1 + NO$_Y$ conversion")
#ax1.plot(model_time_2,model_no2_2a/2.5e10,'--g',linewidth=3.0,alpha=.6)
#ax1.plot(model_time_3,model_no2_3a/2.5e10,'--g',linewidth=3.0,alpha=.6)


#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


#ax1.set_xlim(650,672)
#ax1.set_ylim(1.5e-8,7.5e-8)


ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
#ax1.set_xlabel('time [hr:min]',size=26)
#ax1.set_ylabel('n(NO$_3$) [ppbv]',size=26)
#ax1.set_xlabel('wavelength [nm]',size=26)
#ax1.set_ylabel('extinction [cm$^{-1}$]',size=26)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
#ax1.legend(fontsize=26, loc='upper right')

ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=22,top=True, right=True)
ax1.tick_params(which='minor', length=4,top=True, right=True)
#ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
#ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,10,25,13,40),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,10,25,14,10),0,50, colors='k', linestyles= 'dashed')
ax1.set_xlim(dt.datetime(2024,10,25,13,40),dt.datetime(2024,10,25,14,10))
ax1.set_ylim(-.001,.01)
for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(2)

#ax1.grid()
plt.savefig("no3_catB.png",bbox_inches='tight')

# %%
c360 = np.load('NO2_IASC_CEAS360_364_390.npy')
c450 = np.load('NO2_IASC_CEAS450_432_480_corr.npy')
c660 = np.load('NO2_IASC_CEAS660_650_672_corr.npy')
dfvan = pd.read_csv('no2_2.csv', sep=',', header=None,
                 names=['wave','no2']
                )

# %%
c660.shape
# Out:
# (171, 2)

# %%
dfvan
# Out:
#             wave           no2
# 0      370.38113  5.679760e-19
# 1      370.39436  5.675530e-19
# 2      370.40759  5.671910e-19
# 3      370.42083  5.662880e-19
# 4      370.43406  5.638410e-19
# ...          ...           ...
# 13473  714.05502  1.253680e-20
# 13474  714.10420  1.218440e-20
# 13475  714.15339  1.226850e-20
# 13476  714.20259  1.329170e-20
# 13477  714.25179  1.332040e-20
#
# [13478 rows x 2 columns]

# %%
f = plt.figure(figsize=(19,14))
ax1 = f.add_subplot(111)
#cal_CEAS360=.90
#cal_CEAS450=.857
#cal_CEAS660=.857
#ax1.plot(crds405_dt,np.where(crds405_no2==0, np.nan, crds405_no2),'-k',alpha=1, label="CRDS405")
ax1.plot(dfvan.wave,dfvan.no2,'-k',linewidth=3.0,alpha=.5, label="Vandaele (1996)")
ax1.plot(c360[:,0],c360[:,1],'-m',linewidth=3.0,alpha=1, label="IBBCEAS360")
ax1.plot(c450[:,0],c450[:,1],'-b',linewidth=3.0,alpha=1, label="IBBCEAS450")
ax1.plot(c660[:,0],c660[:,1],'-r',linewidth=3.0,alpha=1, label="IBBCEAS660")

#ax1.plot(model_time_1,model_no2_1/2.5e10,'-c',linewidth=3.0,alpha=1, label="MCMv3.3.1")
#ax1.plot(model_time_2,model_no2_2/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_3,model_no2_3/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_1,model_no2_1/2.5e10,'--g',linewidth=3.0,alpha=.6, label="MCMv3.3.1 + NO$_Y$ conversion")
#ax1.plot(model_time_2,model_no2_2a/2.5e10,'--g',linewidth=3.0,alpha=.6)
#ax1.plot(model_time_3,model_no2_3a/2.5e10,'--g',linewidth=3.0,alpha=.6)


#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


ax1.set_xlim(364,700)
#ax1.set_ylim(1.5e-8,7.5e-8)


#ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
#ax1.set_xlabel('time [hr:min]',size=26)
ax1.set_ylabel('$\\sigma$(NO$_2$) [cm$^{-2}$]',size=26)
ax1.set_xlabel('wavelength [nm]',size=26)
#ax1.set_ylabel('extinction [cm$^{-1}$]',size=26)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
ax1.legend(fontsize=26, loc='upper right',labelcolor='linecolor')

ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=26,top=True, right=True)
ax1.tick_params(which='minor', length=4,top=True, right=True)
ax1.xaxis.set_minor_locator(AutoMinorLocator())
ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,4,10,14,0),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,4,10,15,30),0,50, colors='k', linestyles= 'dashed')

for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(2)
ax1.ticklabel_format(axis='y', style='sci',useMathText=True)
ax1.yaxis.offsetText.set_fontsize(26)
ax1.grid()

plt.savefig("no2_ibbceas.png",bbox_inches='tight')

# %%
f = plt.figure(figsize=(8,6))
ax1 = f.add_subplot(111)
#cal_CEAS360=.90
#cal_CEAS450=.857
#cal_CEAS660=.857
#ax1.plot(crds405_dt,np.where(crds405_no2==0, np.nan, crds405_no2),'-k',alpha=1, label="CRDS405")
ax1.plot(dfvan.wave,dfvan.no2,'-k',linewidth=3.0,alpha=.5, label="Vandaele (1996)")
ax1.plot(c360[:,0],c360[:,1],'-m',linewidth=3.0,alpha=1, label="IBBCEAS360")
ax1.plot(c450[:,0],c450[:,1],'-b',linewidth=3.0,alpha=1, label="IBBCEAS450")
ax1.plot(c660[:,0],c660[:,1],'-r',linewidth=3.0,alpha=1, label="IBBCEAS660")

#ax1.plot(model_time_1,model_no2_1/2.5e10,'-c',linewidth=3.0,alpha=1, label="MCMv3.3.1")
#ax1.plot(model_time_2,model_no2_2/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_3,model_no2_3/2.5e10,'-c',linewidth=3.0,alpha=1)
#ax1.plot(model_time_1,model_no2_1/2.5e10,'--g',linewidth=3.0,alpha=.6, label="MCMv3.3.1 + NO$_Y$ conversion")
#ax1.plot(model_time_2,model_no2_2a/2.5e10,'--g',linewidth=3.0,alpha=.6)
#ax1.plot(model_time_3,model_no2_3a/2.5e10,'--g',linewidth=3.0,alpha=.6)


#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


ax1.set_xlim(630,690)
ax1.set_ylim(0,.4e-19)


#ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
#ax1.set_xlabel('time [hr:min]',size=26)
ax1.set_ylabel('$\\sigma$(NO$_2$) [cm$^{-2}$]',size=26)
ax1.set_xlabel('wavelength [nm]',size=26)
#ax1.set_ylabel('extinction [cm$^{-1}$]',size=26)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
#ax1.legend(fontsize=26, loc='upper right',labelcolor='linecolor')

ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=26,top=True, right=True)
ax1.tick_params(which='minor', length=4,top=True, right=True)
ax1.xaxis.set_minor_locator(AutoMinorLocator())
ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,4,10,14,0),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,4,10,15,30),0,50, colors='k', linestyles= 'dashed')

for axis in ['top', 'bottom', 'left', 'right']:
    ax1.spines[axis].set_linewidth(2)
ax1.ticklabel_format(axis='y', style='sci',useMathText=True)
ax1.yaxis.offsetText.set_fontsize(26)
ax1.grid()

plt.savefig("no2_ibbceas660.png",bbox_inches='tight')

# %%
CEAS360 = sorted(glob.glob('./CorJul/IBBCEAS360/M*.txt'))
CEAS660 = sorted(glob.glob('./CorJul/IBBCEAS660/M*.txt'))
CRDS = sorted(glob.glob('./CorJul/NO2CRDS/M*.txt'))
print(CEAS360,CEAS660,CRDS)
# Out:
# ['./CorJul/IBBCEAS360/M2511041819.txt', './CorJul/IBBCEAS360/M2511051748.txt', './CorJul/IBBCEAS360/M2511061701.txt', './CorJul/IBBCEAS360/M2511071741.txt', './CorJul/IBBCEAS360/M2511081837.txt', './CorJul/IBBCEAS360/M2511101818.txt', './CorJul/IBBCEAS360/M2511111816.txt', './CorJul/IBBCEAS360/M2511121822.txt', './CorJul/IBBCEAS360/M2511131833.txt'] ['./CorJul/IBBCEAS660/M2511042112.txt', './CorJul/IBBCEAS660/M2511051747.txt', './CorJul/IBBCEAS660/M2511061700.txt', './CorJul/IBBCEAS660/M2511071741.txt', './CorJul/IBBCEAS660/M2511081833.txt', './CorJul/IBBCEAS660/M2511101817.txt', './CorJul/IBBCEAS660/M2511111817.txt', './CorJul/IBBCEAS660/M2511121822.txt', './CorJul/IBBCEAS660/M2511131834.txt'] ['./CorJul/NO2CRDS/MC2511041915.txt', './CorJul/NO2CRDS/MC2511051947.txt', './CorJul/NO2CRDS/MC2511061952.txt', './CorJul/NO2CRDS/MC2511071613.txt', './CorJul/NO2CRDS/MC2511081859.txt', './CorJul/NO2CRDS/MC2511102001.txt', './CorJul/NO2CRDS/MC2511111645.txt', './CorJul/NO2CRDS/MC2511121929.txt
# ...

# %%
k=8
Mfile360 = CEAS360[k]
colsM360 = ['time','no2','hono','macr']
Mfile660 = CEAS660[k]
colsM660 = ['time','no3','no2','h2o']
MCfile = CRDS[k]
colsMC = ['time','no2','tau','pres','temp','f_s','f_p','flag']

# %%
M360df = pd.read_csv(Mfile360, sep=' ', header=None, skiprows=2,encoding='utf-8',
                 names=colsM360,
                 index_col='time',parse_dates=['time']
                )
M660df = pd.read_csv(Mfile660, sep=' ', header=None, skiprows=2,encoding='utf-8',
                 names=colsM660,
                 index_col='time',parse_dates=['time']
                )
MCdf = pd.read_csv(MCfile, sep=' ', header=None, skiprows=2,encoding='utf-8',
                 names=colsMC,
                 index_col='time',parse_dates=['time']
                )

# %%
f = plt.figure(figsize=(12,24))
ax1 = f.add_subplot(311)
ax1a = ax1.twinx()
ax2 = f.add_subplot(312)
ax2a = ax2.twinx()
ax3 = f.add_subplot(313)
allsize = 16
timei=dt.datetime(2025,11,13,8,0)
timef=dt.datetime(2025,11,13,19,0)
#########################################################################
ax1.set_title('IBBCEAS360',fontsize=20)
ax1.plot(M360df.index,M360df.no2,'-k',linewidth=3.0,alpha=1, label="NO2")
ax1a.plot(M360df.index,M360df.hono,'-g',linewidth=3.0,alpha=1, label="HONO")
ax1.plot(M360df.index,M360df.macr,'-b',linewidth=3.0,alpha=1, label="MACR")

ax1.xaxis.set_major_formatter(DateFormatter("%H:%M"))
ax1.set_xlabel('time [hr:min]',size=allsize)
ax1.set_ylabel('NO$_2$/MACR [ppbv]',size=allsize)
ax1a.yaxis.set_label_position('right')
ax1a.yaxis.label.set_color('green')
ax1a.set_ylabel('HONO [ppbv]',size=allsize)
ax1a.tick_params(which='major', length=7,labelsize=allsize,top=False, right=True)

ax1.legend(fontsize=allsize, loc='upper right')
ax1a.legend(fontsize=allsize, loc='upper left')
ax1.set_xlim(timei,timef)
ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=allsize,top=False, right=False)
ax1.tick_params(which='minor', length=4,top=False, right=False)

ax1.yaxis.offsetText.set_fontsize(22)
ax1.ticklabel_format(axis='y', style='sci',useMathText=True)
ax1.grid(which='both')

#########################################################################
ax2.set_title('IBBCEAS660',fontsize=20)
ax2.plot(M660df.index,M660df.no3*1000,'-k',linewidth=3.0,alpha=1, label="NO3")
ax2a.plot(M660df.index,M660df.no2,'-g',linewidth=3.0,alpha=1, label="NO2")

ax2.xaxis.set_major_formatter(DateFormatter("%H:%M"))
ax2.set_xlabel('time [hr:min]',size=allsize)
ax2.set_ylabel('NO$_3$ [pptv]',size=allsize)
ax2a.yaxis.set_label_position('right')
ax2a.yaxis.label.set_color('green')
ax2a.set_ylabel('NO$_2$ [ppbv]',size=allsize)
ax2a.tick_params(which='major', length=7,labelsize=allsize,top=False, right=True)

ax2.legend(fontsize=allsize, loc='upper right')
ax2a.legend(fontsize=allsize, loc='upper left')
ax2.set_xlim(timei,timef)
ax2.xaxis.set_minor_locator(AutoMinorLocator(3))
ax2.tick_params(which='both', width=2)
ax2.tick_params(which='major', length=7,labelsize=allsize,top=False, right=False)
ax2.tick_params(which='minor', length=4,top=False, right=False)

ax2.yaxis.offsetText.set_fontsize(22)
ax2.ticklabel_format(axis='y', style='sci',useMathText=True)
ax2.grid(which='both')

###########################################################################
ax3.set_title('NO2CRDS',fontsize=20)
ax3.plot(MCdf.index,MCdf.no2,'-k',linewidth=3.0,alpha=1, label="NO2") 

ax3.xaxis.set_major_formatter(DateFormatter("%H:%M"))
ax3.set_xlabel('time [hr:min]',size=allsize)
ax3.set_ylabel('NO$_2$ [ppbv]',size=allsize)

ax3.legend(fontsize=allsize, loc='upper right')
ax3.set_xlim(timei,timef)
ax3.xaxis.set_minor_locator(AutoMinorLocator(3))
ax3.tick_params(which='both', width=2)
ax3.tick_params(which='major', length=7,labelsize=allsize,top=False, right=True)
ax3.tick_params(which='minor', length=4,top=False, right=True)

ax3.yaxis.offsetText.set_fontsize(22)
ax3.ticklabel_format(axis='y', style='sci',useMathText=True)
ax3.grid(which='both')

#rect1=plt.Rectangle(xy=(dt.datetime(2024,4,10,10,30),-1), width=dt.timedelta(hours=3.5), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect1)


#rect2=plt.Rectangle(xy=(dt.datetime(2024,4,10,15,30),-1), width=dt.timedelta(hours=2), height=35, 
                    #edgecolor='k', facecolor='k', alpha=0.2, linewidth=1)
#ax1.add_patch(rect2)


#ax1.set_xlim(625,700)
#ax1.set_ylim(8,32)


#ax1.set_xlabel('Wavelength [nm]',size=26)
#ax1.set_ylabel('ext [cm$^{-1}$]',size=20)
#ax1.set_title("NO$_2$ measurements, 24/04",size=16)

#ax1.legend(fontsize=26, loc='upper right', bbox_to_anchor=(0.94, 0.99))
#ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
#ax1.yaxis.set_minor_locator(AutoMinorLocator())
#plt.vlines(dt.datetime(2024,4,10,14,0),0,50, colors='k', linestyles= 'dashed')
#plt.vlines(dt.datetime(2024,4,10,15,30),0,50, colors='k', linestyles= 'dashed')

#for axis in ['top', 'bottom', 'left', 'right']:
#    ax1.spines[axis].set_linewidth(2)

#ax1.grid()
plt.savefig("mixing_ratios_20241113.pdf",bbox_inches='tight')

# %%
no2 = np.load('NO2_IASC_CEAS450_432_480.npy')
gly = np.load('CHOCHO_IASC_CEAS450.npy')
ray = np.load('sigma_ray_CEAS450.npy')
print(no2.shape,gly.shape,ray.shape)
# Out:
# (312, 2) (1024, 2) (1024,)

# %%
f = plt.figure(figsize=(12,24))
ax1 = f.add_subplot(311)
ax2 = f.add_subplot(312)
ax2a = ax2.twinx()
allsize = 16
#########################################################################
ax1.set_title('IBBCEAS360',fontsize=20)
ax1.plot(no2[:,0],no2[:,1],'-k',linewidth=3.0,alpha=1, label="NO2")
ax1.xaxis.set_minor_locator(AutoMinorLocator(3))
ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=7,labelsize=allsize,top=False, right=False)
ax1.tick_params(which='minor', length=4,top=False, right=False)

ax1.yaxis.offsetText.set_fontsize(22)
ax1.ticklabel_format(axis='y', style='sci',useMathText=True)
ax1.grid(which='both')

#########################################################################
ax2.set_title('IBBCEAS660',fontsize=20)
ax2.plot(gly[:,0],gly[:,1],'-k',linewidth=3.0,alpha=1, label="gly")
ax2.plot(gly[:,0],ray,'-b',linewidth=3.0,alpha=1, label="ray")

ax2.xaxis.set_minor_locator(AutoMinorLocator(3))
ax2.tick_params(which='both', width=2)
ax2.tick_params(which='major', length=7,labelsize=allsize,top=False, right=False)
ax2.tick_params(which='minor', length=4,top=False, right=False)

ax2.yaxis.offsetText.set_fontsize(22)
ax2.ticklabel_format(axis='y', style='sci',useMathText=True)
ax2.grid(which='both')

###########################################################################
